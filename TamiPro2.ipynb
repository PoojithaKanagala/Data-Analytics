# %% [markdown]
# <a href="https://colab.research.google.com/github/PoojithaKanagala/Data-Analytics/blob/main/TamiPro2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("/content/sample_student_performance.xlsx")
print(df.head())
#average calculation
avg_marks = df["Marks"].mean()
avg_attendance = df["Attendance"].mean()
avg_logins = df["Logins"].mean()

print("Average Marks:", avg_marks)
print("Average Attendance:", avg_attendance)
print("Average Logins:", avg_logins)
#correlation Analysis
correlation_matrix = df[["Marks", "Attendance", "Logins"]].corr()
print(correlation_matrix)
#absentee impact
df["Attendance_Level"] = df["Attendance"].apply(lambda x: "Low" if x < 75 else "High")
impact = df.groupby("Attendance_Level")["Marks"].mean()
print(impact)
#visualization

# Bar chart: Top vs Struggling Students
top_students = df.sort_values("Marks", ascending=False).head(5)
struggling_students = df.sort_values("Marks").head(5)

plt.figure(figsize=(10, 5))
sns.barplot(data=top_students, x="StudentID", y="Marks", color="green", label="Top")
sns.barplot(data=struggling_students, x="StudentID", y="Marks", color="red", label="Struggling")
plt.title("Top vs Struggling Students")
plt.legend()
plt.show()

# Heatmap of correlations
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#   StudentID  Marks  Attendance  Logins
# 0        S1     81          96      40
# 1        S2     44          42      44
# 2        S3     90          76       8
# 3        S4     50          90       6
# 4        S5     53          46      10
# Average Marks: 69.3
# Average Attendance: 68.0
# Average Logins: 28.566666666666666
#                Marks  Attendance    Logins
# Marks       1.000000   -0.054423  0.111227
# Attendance -0.054423    1.000000 -0.150633
# Logins      0.111227   -0.150633  1.000000
# Attendance_Level
# High    69.916667
# Low     68.888889
# Name: Marks, dtype: float64
